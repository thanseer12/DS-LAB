# %% [markdown]
# <a href="https://colab.research.google.com/github/thanseer12/DS-LAB/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/cars1 - cars1.csv")

# %% [markdown]
# 1. Create a Pandas Series containing the values 1, 3, 5, 6, and 8, and display it.

# %%
import pandas as pd
import numpy as np
print("1. Pandas Series:")
s = pd.Series([1, 3, 5, 6, 8])
print(s)
# Out:
# 1. Pandas Series:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %% [markdown]
# 2. Create a DataFrame from a dictionary containing the details of Country, Capital, Area, and
# Population for the BRICS countries, and set the row labels as BR, RU, IN, CH, and SA.

# %%
print("\n2. BRICS Countries DataFrame:")
data = {
    "Country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "Capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "Area": [8515767, 17098242, 3287263, 9596961, 1221037],
    "Population": [214000000, 144000000, 1420000000, 1410000000, 61000000]
}
brics = pd.DataFrame(
    data,
    index=["BR", "RU", "IN", "CH", "SA"]
)
print(brics)
# Out:
# 2. BRICS Countries DataFrame:
#          Country    Capital      Area  Population
# BR        Brazil   Brasilia   8515767   214000000
# RU        Russia     Moscow  17098242   144000000
# IN         India  New Delhi   3287263  1420000000
# CH         China    Beijing   9596961  1410000000
# SA  South Africa   Pretoria   1221037    61000000

# %% [markdown]
# 3. Read the dataset cars1.csv into a DataFrame and:
# o Display the complete dataset.
# o Display the first four records.
# o Display the fifth and sixth records.
# o Display the third row using the iloc[] method.

# %%
cars = pd.read_csv("/content/cars1 - cars1.csv")
print("\nComplete Dataset:")
print(cars)
print("\nFirst Four Records:")
print(cars.head(4))
print("\nFifth and Sixth Records:")
print(cars.iloc[4:6])
print("\nThird Row:")
print(cars.iloc[2])
# Out:
# Complete Dataset:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# 4.Create a DataFrame containing the columns Name, Gender, and Age, and perform
# DataFrame slicing to:
# o Display the first two rows.
# o Display all rows from the third row onwards.

# %%
data2 = {
    "Name": ["Devu", "Gladia", "Nikhitha", "Gowri","Merryl"],
    "Gender": ["Female", "Female", "Female", "Female", "Female"],
    "Age": [21, 22, 23, 20, 24]
}
people = pd.DataFrame(data2)
print("\nOriginal DataFrame:")
print(people)
print("\nFirst Two Rows:")
print(people.iloc[:2])
print("\nThird Row Onwards:")
print(people.iloc[2:])
# Out:
# Original DataFrame:
#        Name  Gender  Age
# 0      Devu  Female   21
# 1    Gladia  Female   22
# 2  Nikhitha  Female   23
# 3     Gowri  Female   20
# 4    Merryl  Female   24
#
# First Two Rows:
#      Name  Gender  Age
# 0    Devu  Female   21
# 1  Gladia  Female   22
#
# Third Row Onwards:
#        Name  Gender  Age
# 2  Nikhitha  Female   23
# 3     Gowri  Female   20
# 4    Merryl  Female   24

# %% [markdown]
# 5.Create a Pandas Series containing four random numbers, and display:
# o The complete Series.
# o The values stored in the Series.
# o The first two elements using head().
# o The last three elements using tail().

# %%
random_series = pd.Series(np.random.rand(4))
print("\nComplete Series:")
print(random_series)
print("\nValues:")
print(random_series.values)
print("\nFirst Two Elements:")
print(random_series.head(2))
print("\nLast Three Elements:")
print(random_series.tail(3))
# Out:
# Complete Series:
# 0    0.680882
# 1    0.687311
# 2    0.929303
# 3    0.197827
# dtype: float64
#
# Values:
# [0.68088162 0.68731112 0.9293028  0.197827  ]
#
# First Two Elements:
# 0    0.680882
# 1    0.687311
# dtype: float64
#
# Last Three Elements:
# 1    0.687311
# 2    0.929303
# 3    0.197827
# dtype: float64

# %% [markdown]
# 6. Create a DataFrame containing the columns Name, Age, and Rating, and display the
# following DataFrame properties:
# o Transpose of the DataFrame.
# o Row and column labels using axes.
# o Data type of each column using dtypes.
# o Whether the DataFrame is empty using empty.
# o Number of dimensions using ndim.
# o Shape of the DataFrame using shape.
# o Total number of elements using size.
# o Values stored in the DataFrame using values.
# o Number of missing values in each column using isnull().sum().

# %%
data3 = {
    "Name": ["Devu", "Gladia", "Nikhitha", "Gowri"],
    "Age": [21, 22, 23, 20],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data3)
print("\nOriginal DataFrame:")
print(df)
print("\nTranspose:")
print(df.T)
print("\nAxes:")
print(df.axes)
print("\nData Types:")
print(df.dtypes)
print("\nIs DataFrame Empty?")
print(df.empty)
print("\nNumber of Dimensions:")
print(df.ndim)
print("\nShape:")
print(df.shape)
print("\nSize:")
print(df.size)
print("\nValues:")
print(df.values)
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Original DataFrame:
#        Name  Age  Rating
# 0      Devu   21     4.5
# 1    Gladia   22     4.0
# 2  Nikhitha   23     4.8
# 3     Gowri   20     4.2
#
# Transpose:
#            0       1         2      3
# Name    Devu  Gladia  Nikhitha  Gowri
# Age       21      22        23     20
# Rating   4.5     4.0       4.8    4.2
#
# Axes:
# [RangeIndex(start=0, stop=4, step=1), Index(['Name', 'Age', 'Rating'], dtype='object')]
#
# Data Types:
# Name       object
# Age         int64
# Rating    float64
# dtype: object
#
# Is DataFrame Empty?
# False
#
# Number of Dimensions:
# 2
#
# Shape:
# (4, 3)
#
# Size:
# 12
#
# Values:
# [['Devu' 21 4.5]
#  ['Gladia' 22 4.0]
#  ['Nikhitha' 23 4.8]
#  ['Gowri' 20 4.2]]
#
# Missing Values:
# Name      0
# Age       0
# Rating    0
# dtype: int64
